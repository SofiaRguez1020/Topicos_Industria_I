# %% [markdown]
# <a href="https://colab.research.google.com/github/SofiaRguez1020/Topicos_Industria_I/blob/main/Session2_Sofia_Rodriguez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #MODULES

# %%
import math
import numpy as np
import matplotlib. pyplot as plt
import plotly.graph_objects as go

from scipy.stats import exponweib

import pandas as pd
from scipy.stats import levy_stable

# %% [markdown]
# #CLASSES

# %%
################# http://www.pygame.org/wiki/2DVectorClass ##################
class Vec2d(object):
    """2d vector class, supports vector and scalar operators,
       and also provides a bunch of high level functions
       """
    __slots__ = ['x', 'y']

    def __init__(self, x_or_pair, y = None):
        if y == None:
            self.x = x_or_pair[0]
            self.y = x_or_pair[1]
        else:
            self.x = x_or_pair
            self.y = y

    # Addition
    def __add__(self, other):
        if isinstance(other, Vec2d):
            return Vec2d(self.x + other.x, self.y + other.y)
        elif hasattr(other, "__getitem__"):
            return Vec2d(self.x + other[0], self.y + other[1])
        else:
            return Vec2d(self.x + other, self.y + other)

    # Subtraction
    def __sub__(self, other):
        if isinstance(other, Vec2d):
            return Vec2d(self.x - other.x, self.y - other.y)
        elif (hasattr(other, "__getitem__")):
            return Vec2d(self.x - other[0], self.y - other[1])
        else:
            return Vec2d(self.x - other, self.y - other)

    # Vector length
    def get_length(self):
        return math.sqrt(self.x**2 + self.y**2)

    # rotate vector
    def rotated(self, angle):
        cos = math.cos(angle)
        sin = math.sin(angle)
        x = self.x*cos - self.y*sin
        y = self.x*sin + self.y*cos
        return Vec2d(x, y)

# %% [markdown]
# #About RVS and Histograms

# %%
# Argumentos para Weibull
a = 2.89
c = 1.95
# Valor de resolution
resolution = 200
aux_domain = np.linspace(0, 3, resolution)

exponweib_pdf = np.array([exponweib.pdf(i, a, c) for i in aux_domain])

# %%
fig_exponweib_pdf = go.Figure()

fig_exponweib_pdf.add_trace(go.Scatter(x = aux_domain,
                                       y = exponweib_pdf,
                                       marker = dict(size=2),
                                       mode = 'lines',
                                       name = 'Weibull',
                                       showlegend = True))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
aux_vector = np.linspace (0,1, sample_size)
fig, ax = plt.subplots(1,1)
ax.plot (aux_vector, r)

# %%
sample_size = 1500
r = exponweib.rvs(a,c, size=sample_size)

fig, ax = plt.subplots(1,1)
fig.set_figheight(5)
fig.set_figwidth(10)

ax.hist(r, bins=100, density=True, histtype='stepfilled', alpha=0.2, label='Weibull histo')
ax.plot(aux_domain, exponweib_pdf, 'r-', lw=5, alpha=0.6, label='Weibull pdf')
ax.legend(loc='best')
plt.show()

# %% [markdown]
# #Pandas

# %%
housing_df = pd.read_csv('sample_data/california_housing_test.csv')

# %%
r
# Out:
# array([1.70740645, 1.75648082, 2.44039613, ..., 0.9487216 , 1.75413764,
#        1.38095809])

# %%
housing_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
housing_df.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 7    -120.65     35.48                19.0       2310.0           471.0
# 8    -122.84     38.40                15.0       3080.0           617.0
# 9    -118.02     34.08                31.0       2402.0           632.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# ...

# %%
housing_df.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
housing_df.tail(10)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2990    -118.23     34.09                49.0       1638.0           456.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
# 2992    -122.33     37.39                52.0        573.0           102.0
# 2993    -117.91     33.60                37.0       2088.0           510.0
# 2994    -117.93     33.86                35.0        931.0           181.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2990      1500.0       430.0         2.6923            150000.0
# ...

# %%
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
housing_df.total_rooms.describe()
# Out:
# count     3000.000000
# mean      2599.578667
# std       2155.593332
# min          6.000000
# 25%       1401.000000
# 50%       2106.000000
# 75%       3129.000000
# max      30450.000000
# Name: total_rooms, dtype: float64

# %%
#Explorando renglones
housing_df.loc[0]
# Out:
# longitude               -122.0500
# latitude                  37.3700
# housing_median_age        27.0000
# total_rooms             3885.0000
# total_bedrooms           661.0000
# population              1537.0000
# households               606.0000
# median_income              6.6085
# median_house_value    344700.0000
# Name: 0, dtype: float64

# %%
housing_df.iloc[0]
# Out:
# longitude               -122.0500
# latitude                  37.3700
# housing_median_age        27.0000
# total_rooms             3885.0000
# total_bedrooms           661.0000
# population              1537.0000
# households               606.0000
# median_income              6.6085
# median_house_value    344700.0000
# Name: 0, dtype: float64

# %%
housing_df.iloc[0:4] #returns all rows but the last one
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0

# %%
housing_df.iloc[10:14]
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10    -118.24     33.98                45.0        972.0           249.0
# 11    -119.12     35.85                37.0        736.0           166.0
# 12    -121.93     37.25                36.0       1089.0           182.0
# 13    -117.03     32.97                16.0       3936.0           694.0
#
#     population  households  median_income  median_house_value
# 10      1288.0       261.0         2.2054            125000.0
# 11       564.0       138.0         2.4167             58300.0
# 12       535.0       170.0         4.6900            252600.0
# 13      1935.0       659.0         4.5625            231200.0

# %%
housing_df.iloc[10:14].latitude
# Out:
# 10    33.98
# 11    35.85
# 12    37.25
# 13    32.97
# Name: latitude, dtype: float64

# %%
housing_df.iloc[10:14].latitude.values
# Out:
# array([33.98, 35.85, 37.25, 32.97])

# %%
#Explorando columnas
housing_df['housing_median_age']
# Out:
# 0       27.0
# 1       43.0
# 2       27.0
# 3       28.0
# 4       19.0
#         ...
# 2995    23.0
# 2996    27.0
# 2997    10.0
# 2998    40.0
# 2999    42.0
# Name: housing_median_age, Length: 3000, dtype: float64

# %%
housing_df['housing_median_age'].mean()
# Out:
# 28.845333333333333

# %%
housing_df[(housing_df.housing_median_age<30)]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# ...         ...       ...                 ...          ...             ...
# 2987    -121.97     37.29                25.0       4096.0           743.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# # Browninan motion 2D - with vectors and pandas

# %%
#Init variables
n_steps = 10000
s_pos = [0, 0]
speed = 6

#Init velocity vector
velocity = Vec2d(speed, 0)
BM_2d_df = pd.DataFrame(columns=['x_pos','y_pos'])

temp_df = pd.DataFrame([{'x_pos':s_pos[0], 'y_pos':s_pos[1]}])

#Concatenamos
BM_2d_df = pd.concat([BM_2d_df, temp_df], ignore_index=True)

for i in range(n_steps):
  turn_angle = np.random.choice([0, np.pi/2, np.pi, 3*np.pi/2])
  turn_angle = np.random.uniform(low=-np.pi, high = np.pi)
  velocity = velocity.rotated(turn_angle)
  temp_df = pd.DataFrame([{'x_pos':BM_2d_df.x_pos[i]+velocity.x, 'y_pos':BM_2d_df.y_pos[i]+velocity.y}])
  BM_2d_df = pd.concat([BM_2d_df, temp_df], ignore_index=True)

# %%
BM_2d_df.head()
# Out:
#   x_pos y_pos
# 0     0     0
# 1   6.0   0.0
# 2   0.0   0.0
# 3   0.0   6.0
# 4   6.0   6.0

# %%
fig_BM_pdf = go.Figure()

fig_BM_pdf.add_trace(go.Scatter(x = BM_2d_df.x_pos,
                                y = BM_2d_df.y_pos,
                                marker = dict(size=2),
                                mode = 'lines',
                                name = 'BM 2D',
                                showlegend = True))

fig_BM_pdf.update_layout(title_text = 'BM trajectory in 2D',
                         autosize=False,
                         width=800,
                         height=800)
fig_BM_pdf.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Init variables
std_motion_steps = 3.0
levy_exponent = 1.9
beta = 1.0

aux_domain = np.linspace(std_motion_steps-5, std_motion_steps+5, 400)
Levy_pdf = np.array([levy_stable.pdf(i, alpha=levy_exponent, beta=beta, loc=std_motion_steps) for i in aux_domain])

# %%
fig_Levy_pdf = go.Figure()

fig_Levy_pdf.add_trace(go.Scatter(x = aux_domain,
                                y = Levy_pdf,
                                marker = dict(size=2),
                                mode = 'lines',
                                name = 'Levy',
                                showlegend = True))

fig_Levy_pdf.update_layout(title_text = 'Levy PDF')
fig_Levy_pdf.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
